# %%
import pandas as pd
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

# %%
test_data1 = np.array(["a", "b", "c", "d"])
test_series1 = pd.Series(test_data1)
test_dataframe1 = pd.DataFrame(test_series1)

print(test_data1)
print(test_series1)
print(test_dataframe1)
# Out:
# ['a' 'b' 'c' 'd']
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: str
#    0
# 0  a
# 1  b
# 2  c
# 3  d
